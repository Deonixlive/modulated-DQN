# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

env = gym.make("CartPole-v1")

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
t = torch.tensor([5, 5, 5], dtype=torch.int64, device='cuda')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 t = torch.tensor([5, 5, 5], dtype=torch.int64, device='cuda')
#
# File ~/miniconda3/envs/rl/lib/python3.13/site-packages/torch/cuda/__init__.py:378, in _lazy_init()
#     376 if "CUDA_MODULE_LOADING" not in os.environ:
#     377     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 378 torch._C._cuda_init()
#     379 # Some of the queued calls may reentrantly call _lazy_init();
#     380 # we need to just return without initializing in that case.
#     381 # However, we must not let any *other* threads in!
#     382 _tls.is_initializing = True
#
# RuntimeError: No HIP GPUs are available
